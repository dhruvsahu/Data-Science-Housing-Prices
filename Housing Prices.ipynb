# %% [markdown]
# Housing-Prices

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("USA_Housing.csv")

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(df)
plt.tight_layout()

# %%
sns.displot(df['Price'])

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# Avg. Area Income                                  0.019788        -0.016234
# Avg. Area House Age                               0.006149        -0.018743
# Avg. Area Number of Rooms                         0.462695         0.002040
# Avg. Area Number of Bedrooms                      1.000000        -0.022168
# Area Population                                  -0.022168         1.000000
# Price                                             0.171071         0.408556
#
#                                  Price
# Avg. Area Income              0.639734
# Avg. Area House Age           0.452543
# Avg. Area Number of Rooms     0.335664
# Avg. Area Number of Bedrooms  0.171071
# Area Population               0.408556
# Price                         1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Data-Science-Housing-Prices\Housing Prices.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data-Science-Housing-Prices/Housing%20Prices.ipynb#ch0000011?line=0'>1</a> from sklearn.model_selection import train_test_split
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\model_selection\__init__.py:23, in <module>
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/__init__.py?line=19'>20</a> from ._split import train_test_split
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/__init__.py?line=20'>21</a> from ._split import check_cv
# ---> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/__init__.py?line=22'>23</a> from ._validation import cross_val_score
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/__init__.py?line=23'>24</a> from ._validation import cross_val_predict
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/__init__.py?line=24'>25</a> from ._validation import cross_validate
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:32, in <module>
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/_validation.py?line=29'>30</a> from ..utils.fixes import delayed
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/_validation.py?line=30'>31</a> from ..utils.metaestimators import _safe_split
# ---> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/_validation.py?line=31'>32</a> from ..metrics import check_scoring
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/_validation.py?line=32'>33</a> from ..metrics._scorer import _check_multimetric_scoring, _MultimetricScorer
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/model_selection/_validation.py?line=33'>34</a> from ..exceptions import FitFailedWarning
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\metrics\__init__.py:7, in <module>
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=0'>1</a> """
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=1'>2</a> The :mod:`sklearn.metrics` module includes score functions, performance metrics
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=2'>3</a> and pairwise metrics and distance computations.
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=3'>4</a> """
# ----> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=6'>7</a> from ._ranking import auc
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=7'>8</a> from ._ranking import average_precision_score
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/__init__.py?line=8'>9</a> from ._ranking import coverage_error
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:37, in <module>
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=34'>35</a> from ..utils.sparsefuncs import count_nonzero
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=35'>36</a> from ..exceptions import UndefinedMetricWarning
# ---> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=36'>37</a> from ..preprocessing import label_binarize
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=37'>38</a> from ..utils._encode import _encode, _unique
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=39'>40</a> from ._base import (
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=40'>41</a>     _average_binary_score,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=41'>42</a>     _average_multiclass_ovo_score,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=42'>43</a>     _check_pos_label_consistency,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/metrics/_ranking.py?line=43'>44</a> )
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py:8, in <module>
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=0'>1</a> """
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=1'>2</a> The :mod:`sklearn.preprocessing` module includes scaling, centering,
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=2'>3</a> normalization, binarization methods.
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=3'>4</a> """
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=5'>6</a> from ._function_transformer import FunctionTransformer
# ----> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=7'>8</a> from ._data import Binarizer
#       <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=8'>9</a> from ._data import KernelCenterer
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/__init__.py?line=9'>10</a> from ._data import MinMaxScaler
#
# File c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:19, in <module>
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=15'>16</a> from scipy import optimize
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=16'>17</a> from scipy.special import boxcox
# ---> <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=18'>19</a> from ..base import (
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=19'>20</a>     BaseEstimator,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=20'>21</a>     TransformerMixin,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=21'>22</a>     _OneToOneFeatureMixin,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=22'>23</a>     _ClassNamePrefixFeaturesOutMixin,
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=23'>24</a> )
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=24'>25</a> from ..utils import check_array
#      <a href='file:///c%3A/Users/Dhruv/anaconda3/lib/site-packages/sklearn/preprocessing/_data.py?line=25'>26</a> from ..utils.extmath import _incremental_mean_and_var, row_norms
#
# ImportError: cannot import name '_ClassNamePrefixFeaturesOutMixin' from 'sklearn.base' (c:\Users\Dhruv\anaconda3\lib\site-packages\sklearn\base.py)
